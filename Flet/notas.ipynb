# %% [markdown]
# # Creacion de entorno
#
# cd C:\Users\Oberb\OneDrive\Documentos\Codigo\Flet
#
# python -m venv .venv
#
# .venv\Scripts\activate
#
# python -m pip install --upgrade pip
#
# *Para la creación de un entorno virtual.*
#
# ## para salir solo:
#
# deactivate
#
# ## para volver a entrar
#
# .\.venv\Scripts\Activate.ps1
#
# o
#
# .venv\Scripts\activate

# %% [markdown]
# # variable .venv
#
# Los archivos van fuera de la carpeta .venv
#
# # ejecutar
#
#
# ```console
# flet run counter.py
# flet run --web counter.py
#
# ```

# %% [markdown]
# # Para Github
#
# siempre se debe usar deactivate para salir del entorno cuando vas a subir a github
