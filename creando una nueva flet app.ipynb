# %%
flet create
# Out:
#   Cell In[1], line 1
#     flet create
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![{870DDD00-6648-4325-BDA4-550BD1400374}.png](attachment:{870DDD00-6648-4325-BDA4-550BD1400374}.png)
